# %%
import pandas as pd

# %%
releases = pd.read_pickle('../data/releases.zip')

# %%
releases.columns
# Out:
# Index(['version', 'semantic_version', 'prefix', 'suffix', 'lang', 'head',
#        'time', 'cycle', 'committers', 'commits', 'merges', 'base_releases',
#        'base_releases_qnt', 'range_commits', 'range_base_releases',
#        'range_tpos', 'range_fpos', 'range_fneg', 'time_commits',
#        'time_base_releases', 'time_tpos', 'time_fpos', 'time_fneg',
#        'time_naive_commits', 'time_naive_base_releases', 'time_naive_tpos',
#        'time_naive_fpos', 'time_naive_fneg', 'time_expert_commits',
#        'time_expert_base_releases', 'time_expert_tpos', 'time_expert_fpos',
#        'time_expert_fneg', 'range_precision', 'range_recall', 'range_fmeasure',
#        'time_precision', 'time_recall', 'time_fmeasure',
#        'time_naive_precision', 'time_naive_recall', 'time_naive_fmeasure',
#        'time_expert_precision', 'time_expert_recall', 'time_expert_fmeasure',
#        'cycle_sec'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 1000)

# %%
releases.reset_index().groupby(['lang']).sample(1)
# Out:
#                                                 project     name version  \
# 10129                                         tmux/tmux      1.8     1.8
# 9511   MaterialDesignInXAML/MaterialDesignInXamlToolkit   v2.3.1   2.3.1
# 8708                                  electron/electron   v3.0.2   3.0.2
# 12682                                  v2ray/v2ray-core  v4.23.0  4.23.0
# 3699                              elastic/elasticsearch  v0.16.5  0.16.5
# 1859                                     vercel/next.js    2.4.5   2.4.5
# 6247                                    laravel/laravel   v3.0.1   3.0.1
# 6078                                      XX-net/XX-Net   3.1.15  3.1.15
# 11718                               CocoaPods/CocoaPods    0.3.2   0.3.2
# 2034                               microsoft/TypeScript   v3.7.5   3.7.5
#
#       semantic_version prefix suffix        lang  \
# 10129            1.8.0   None   None           c
# 9511             2.3.1      v   None          c#
# ...

# %%
releases.loc['tmux/tmux'].sample(10)
# Out:
#      version semantic_version prefix suffix lang  \
# name
# 2.4      2.4            2.4.0   None   None    c
# 2.6      2.6            2.6.0   None   None    c
# 1.2      1.2            1.2.0   None   None    c
# 1.0      1.0            1.0.0   None   None    c
# 1.5      1.5            1.5.0   None   None    c
# 0.8      0.8            0.8.0   None   None    c
# 2.3      2.3            2.3.0   None   None    c
# 1.1      1.1            1.1.0   None   None    c
# 3.0      3.0            3.0.0   None   None    c
# 1.3      1.3            1.3.0   None   None    c
#
#                                           head                      time  \
# name
# 2.4   f21cb71fbe79c8949edc3c1d300aa783382a0d77 2017-04-20 10:52:35+00:00
# 2.6   bd71cbbe276432ce8869baa0f2d55433e1ab820c 2017-10-05 13:32:09+00:00
# 1.2   cd1ae9e79b70bf36f08a4f985982ff9245bc98f3 2010-03-10 15:18:50+00:00
# 1.0   be20fc8699e8861c8b176030d2100b1cc502b034 2009-09-20 18:54:22+00:00
# ...

# %%
releases.loc['MaterialDesignInXAML/MaterialDesignInXamlToolkit'].sample(10)
# Out:
#        version semantic_version prefix suffix lang  \
# name
# v2.3.0   2.3.0            2.3.0      v   None   c#
# v3.2.0   3.2.0            3.2.0      v   None   c#
# v3.0.0   3.0.0            3.0.0      v   None   c#
# v2.1.0   2.1.0            2.1.0      v   None   c#
# v2.2.0   2.2.0            2.2.0      v   None   c#
# 2.6.0    2.6.0            2.6.0   None   None   c#
# 3.1.1    3.1.1            3.1.1   None   None   c#
# v1.5.0   1.5.0            1.5.0      v   None   c#
# v3.1.3   3.1.3            3.1.3      v   None   c#
# v2.0.0   2.0.0            2.0.0      v   None   c#
#
#                                             head                      time  \
# name
# v2.3.0  092f55120163633d5350147f86cc4b814f8c9bf6 2017-03-08 07:59:48+00:00
# v3.2.0  04f1326ce9ebb591ed99e21b226b9eb78eaab29a 2020-09-20 07:33:12+00:00
# v3.0.0  09c6fd22fea6563ecc5d955b640777e999816201 2019-12-09 05:48:45+00:00
# v2.1.0  bf669f5ebf7e58fc5b93791b0d5e79de160d9c3f 2016-08-26 05:31:57+00:00
# ...

# %%
releases.loc['electron/electron'].sample(10)
# Out:
#         version semantic_version prefix suffix lang  \
# name
# v0.10.4  0.10.4           0.10.4      v   None  c++
# v6.0.0    6.0.0            6.0.0      v   None  c++
# v4.0.5    4.0.5            4.0.5      v   None  c++
# v4.2.0    4.2.0            4.2.0      v   None  c++
# v0.15.5  0.15.5           0.15.5      v   None  c++
# v8.0.3    8.0.3            8.0.3      v   None  c++
# v1.6.2    1.6.2            1.6.2      v   None  c++
# v0.32.0  0.32.0           0.32.0      v   None  c++
# v0.11.7  0.11.7           0.11.7      v   None  c++
# v0.20.2  0.20.2           0.20.2      v   None  c++
#
#                                              head                      time  \
# name
# v0.10.4  7cfff6203706e0414672a19fc5b61d57fb6bcdd1 2014-03-01 14:54:22+00:00
# v6.0.0   825bd6d45ed0914bd8749c077e6d7533efd5d9c2 2019-07-29 18:15:14+00:00
# v4.0.5   55c48efb907152dac8cb04fe0232801b38ae7bbc 2019-02-14 22:09:23+00:00
# ...

# %%
releases.loc['v2ray/v2ray-core'].sample(10)
# Out:
#         version semantic_version prefix suffix lang  \
# name
# v0.14.1  0.14.1           0.14.1      v   None   go
# v2.19      2.19           2.19.0      v   None   go
# v4.20.0  4.20.0           4.20.0      v   None   go
# v0.13      0.13           0.13.0      v   None   go
# v1.14      1.14           1.14.0      v   None   go
# v4.16.1  4.16.1           4.16.1      v   None   go
# v3.30      3.30           3.30.0      v   None   go
# v2.20      2.20           2.20.0      v   None   go
# v0.6.1    0.6.1            0.6.1      v   None   go
# v2.16.4  2.16.4           2.16.4      v   None   go
#
#                                              head                      time  \
# name
# v0.14.1  869cd46450389b2cf33b35b9fb5d5ea73a6ce47e 2015-11-22 23:20:07+00:00
# v2.19    587ada599c8cf8ac3e91ff561854d9c7af211620 2017-02-17 16:31:53+00:00
# v4.20.0  fffa6de47a2feeb85c9c63e4ec0246f95f59200b 2019-07-12 08:42:59+00:00
# ...

# %%
releases.loc['elastic/elasticsearch'].sample(10)
# Out:
#         version semantic_version prefix suffix  lang  \
# name
# v0.90.9  0.90.9           0.90.9      v   None  java
# v0.90.6  0.90.6           0.90.6      v   None  java
# v5.4.2    5.4.2            5.4.2      v   None  java
# v1.4.4    1.4.4            1.4.4      v   None  java
# v5.4.0    5.4.0            5.4.0      v   None  java
# v1.4.5    1.4.5            1.4.5      v   None  java
# v7.6.2    7.6.2            7.6.2      v   None  java
# v0.90.3  0.90.3           0.90.3      v   None  java
# v7.9.1    7.9.1            7.9.1      v   None  java
# v5.4.1    5.4.1            5.4.1      v   None  java
#
#                                              head                      time  \
# name
# v0.90.9  a968646da4b6a2d9d8bca9e51e92597fe64e8d1a 2013-12-23 10:34:19+00:00
# v0.90.6  e2a24efdde0cb7cc1b2071ffbbd1fd874a6d8d6b 2013-11-04 13:35:37+00:00
# v5.4.2   929b078898b27e05476cc6212bc0b96d3eb8b7b1 2017-06-21 07:51:58+00:00
# ...

# %%
releases.loc['vercel/next.js'].sample(10)
# Out:
#        version semantic_version prefix suffix        lang  \
# name
# 3.0.2    3.0.2            3.0.2   None   None  javascript
# 3.2.3    3.2.3            3.2.3   None   None  javascript
# v8.0.4   8.0.4            8.0.4      v   None  javascript
# 2.4.4    2.4.4            2.4.4   None   None  javascript
# v9.3.0   9.3.0            9.3.0      v   None  javascript
# 1.1.1    1.1.1            1.1.1   None   None  javascript
# 2.2.0    2.2.0            2.2.0   None   None  javascript
# 1.1.2    1.1.2            1.1.2   None   None  javascript
# 2.1.1    2.1.1            2.1.1   None   None  javascript
# 4.1.2    4.1.2            4.1.2   None   None  javascript
#
#                                             head                      time  \
# name
# 3.0.2   42e21288a91b2f58d90c3cc782766611de30630f 2017-08-09 06:35:16+00:00
# 3.2.3   5fea0f5e709461b450386f1d306367653829db36 2018-01-24 20:32:16+00:00
# v8.0.4  e6e4a15284be1eb93cda929e4b6f48d87cbe664d 2019-04-02 00:45:38+00:00
# ...

# %%
releases.loc['laravel/laravel'].sample(10)
# Out:
#         version semantic_version prefix suffix lang  \
# name
# v5.6.21  5.6.21           5.6.21      v   None  php
# v5.4.23  5.4.23           5.4.23      v   None  php
# v3.2.5    3.2.5            3.2.5      v   None  php
# v4.0.5    4.0.5            4.0.5      v   None  php
# v6.2.0    6.2.0            6.2.0      v   None  php
# v3.0.4    3.0.4            3.0.4      v   None  php
# v5.1.1    5.1.1            5.1.1      v   None  php
# v5.4.3    5.4.3            5.4.3      v   None  php
# v5.2.27  5.2.27           5.2.27      v   None  php
# v5.3.0    5.3.0            5.3.0      v   None  php
#
#                                              head                      time  \
# name
# v5.6.21  3f92cf66f53b3b53467497acc0d2a00cbd7b65f0 2018-05-08 19:42:54+00:00
# v5.4.23  0f0178a577d3d7f41d308d2ce91b1e2ce5e27cad 2017-05-11 12:42:02+00:00
# v3.2.5   1203473469b1fad5e803182bfb3350c28649963f 2012-08-17 14:18:16+00:00
# ...

# %%
releases.loc['XX-net/XX-Net'].sample(10)
# Out:
#        version semantic_version prefix suffix    lang  \
# name
# 3.6.3    3.6.3            3.6.3   None   None  python
# 1.3.6    1.3.6            1.3.6   None   None  python
# 3.11.9  3.11.9           3.11.9   None   None  python
# 3.8.2    3.8.2            3.8.2   None   None  python
# 3.10.8  3.10.8           3.10.8   None   None  python
# 3.8.0    3.8.0            3.8.0   None   None  python
# 1.13.6  1.13.6           1.13.6   None   None  python
# 4.3.0    4.3.0            4.3.0   None   None  python
# 3.6.9    3.6.9            3.6.9   None   None  python
# 3.14.2  3.14.2           3.14.2   None   None  python
#
#                                             head                      time  \
# name
# 3.6.3   7ace0ffe8e98804f2a066505094fef71ee481fa7 2017-09-24 13:36:49+00:00
# 1.3.6   196bc2292c3f40aa342d548cf8ce96aacfe3b4e2 2015-03-17 12:25:38+00:00
# 3.11.9  161eca3670f9575a87ae1496d1f889c07a6a1c57 2018-04-09 01:51:30+00:00
# ...

# %%
releases.loc['CocoaPods/CocoaPods'].sample(10)
# Out:
#        version semantic_version prefix suffix  lang  \
# name
# 0.22.3  0.22.3           0.22.3   None   None  ruby
# 1.7.5    1.7.5            1.7.5   None   None  ruby
# 0.3.0    0.3.0            0.3.0   None   None  ruby
# 0.3.1    0.3.1            0.3.1   None   None  ruby
# 0.0.7    0.0.7            0.0.7   None   None  ruby
# 1.7.1    1.7.1            1.7.1   None   None  ruby
# 0.38.2  0.38.2           0.38.2   None   None  ruby
# 0.5.0    0.5.0            0.5.0   None   None  ruby
# 0.16.0  0.16.0           0.16.0   None   None  ruby
# 0.35.0  0.35.0           0.35.0   None   None  ruby
#
#                                             head                      time  \
# name
# 0.22.3  d083e9ad8cf637cbabc74145a53e8f695daf071e 2013-07-23 20:52:31+00:00
# 1.7.5   965af3c51afec52394d57a8ed2e8a0ce0f28ade7 2019-07-19 16:58:44+00:00
# 0.3.0   bb3535afeca43a3b386ab2fc25a49f06193a07d6 2011-11-13 00:43:25+00:00
# ...

# %%
releases.loc['microsoft/TypeScript'].sample(10)
# Out:
#        version semantic_version prefix suffix        lang  \
# name
# v2.6.0   2.6.0            2.6.0      v   None  typescript
# v2.1.4   2.1.4            2.1.4      v   None  typescript
# v2.4.1   2.4.1            2.4.1      v   None  typescript
# v2.1.5   2.1.5            2.1.5      v   None  typescript
# v2.5.3   2.5.3            2.5.3      v   None  typescript
# v3.7.4   3.7.4            3.7.4      v   None  typescript
# v2.7.2   2.7.2            2.7.2      v   None  typescript
# v2.7.1   2.7.1            2.7.1      v   None  typescript
# v1.8.7   1.8.7            1.8.7      v   None  typescript
# v3.2.1   3.2.1            3.2.1      v   None  typescript
#
#                                             head                      time  \
# name
# v2.6.0  1c790bc4f9bf5102b98c50839ced416ae61b5612 2017-10-04 20:56:34+00:00
# v2.1.4  409311f3634afdcf0423670661758fe9e7c87a99 2016-12-05 19:49:56+00:00
# v2.4.1  8b2fe136f8cac532445bb3de89abd134592172d1 2017-06-23 00:33:19+00:00
# ...
